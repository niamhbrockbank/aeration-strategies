# %% [markdown]
# # Oxygen Demand

# %% [markdown]
# This script plots the CW Bill Young 2016 data to plots using plotly. This includes the blue-green algae, dissolved oxygen, temperature, and oxygen demand.

# %%
##Calling the relevant libraries

#plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots

#pandas
import pandas as pd

# %% [markdown]
# ### Plot Code

# %%
#Open the temperature csv file
Data = pd.read_csv("DailyODInterval.csv")
#WeathData = pd.read_csv("AirTemp.csv")

#Plot the figure
fig = make_subplots(rows = 1, cols = 1)

#Reservoir Data Heatmap
fig.add_trace((go.Heatmap(
                   z = Data.AVEg_m2_day, #Asign the axes
                   x = Data.date,
                   y = Data.surf_elevm_round, #CONVERT to metres from feet
                   #connectgaps = True, #Formatting from here down
                   colorscale = "RdBu_r", #r indicates that colorscale is reversed
                   colorbar_title = '<i>Oxygen Demand <br>(gO2/m2/day)</i>',
                   zmax= 5,
                   zmin = 2,
                   zsmooth = 'best'
                    )),
              row = 1, col = 1)

##Formatting
#The same formatting will be used for all of the plots
#dtick is distance between ticks use range = [start number, end number] to set range...  
#Date-time axis formatting: https://community.plotly.com/t/how-to-make-the-messy-date-ticks-organized/7477/2
fig.layout.template = "simple_white"
fig.update_layout(showlegend = False)

#Update Heatmap Axes
fig.update_xaxes(ticks = "outside", #dtick = 14, tick0 = '2016-03-19', #Axis Labels
                tickfont = dict(size = 10), tickformat = '%e %b',
                #title = "<b>Date (2016)</b>", title_standoff = 10, titlefont_size = 11, #Axis Title
                showline = True, linewidth = 1, linecolor = 'black', mirror = True, #Axis Line
                fixedrange = True, #Disabling zoom
                row = 1, col = 1) 

fig.update_yaxes(ticks = "outside", tick0 = 70, dtick = 5, #Axis Labels
                tickfont = dict(size = 10), 
                title = "<b>Elevation (m)</b>", title_standoff = 5, titlefont_size = 11,#Axis Title
                showline = True, linewidth = 1, linecolor = 'black', mirror = True, #Axis Line
                fixedrange = True, #Disabling zoom
                range = [19,41],
                row = 1, col = 1)

fig.show()
# Out:
# <div>                            <div id="3469456a-98a5-429b-81a3-d025ad34f656" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3469456a-98a5-429b-81a3-d025ad34f656")) {                    Plotly.newPlot(                        "3469456a-98a5-429b-81a3-d025ad34f656",                        [{"colorbar": {"title": {"text": "<i>Oxygen Demand <br>(gO2/m2/day)</i>"}}, "colorscale": [[0.0, "rgb(5,48,97)"], [0.1, "rgb(33,102,172)"], [0.2, "rgb(67,147,195)"], [0.3, "rgb(146,197,222)"], [0.4, "rgb(209,229,240)"], [0.5, "rgb(247,247,247)"], [0.6, "rgb(253,219,199)"], [0.7, "rgb(244,165,130)"], [0.8, "rgb(214,96,77)"], [0.9, "rgb(178,24,43)"], [1.0, "rgb(103,0,31)"]], "type": "heatmap", "x": ["2016-03-20", "2016-03-21", "2016-03-22", "2016-03-23", "2016-03-24", "2016-03-25", "2016-03-26", "2016-03-27", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-01", "2016-04-02", "2016-04-03", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-07", "2016-04-08", "2016-04-09", "2016-04-10", "2016-04-11", "2016-04-12", "2016-04-13", "2016-04-14", "2016-04-15", "2016-04-16", "2016-04-17", "2016-04-18", "2016-04-19", "2016-04-21", "2016-04-22", "2016-04-23", "2016-04-24", "2016-04-25", "2016-04-26", "2016-04-27", "2016-04-28", "2016-04-29", "2016-04-30", "2016-05-01", "2016-05-02", "2016-05-03", "2016-05-04", "2016-05-05", "2016-05-06", "2016-05-07", "2016-05-08", "2016-05-09", "2016-05-10", "2016-05-11", "2016-05-12", "2016-05-13", "2016-05-14", "2016-05-23", "2016-05-24", "2016-05-25", "2016-05-26", "2016-05-27", "2016-05-28", "2016-05-29", "2016-05-30", "2016-05-31", "2016-06-01", "2016-06-02", "2016-06-03", "2016-06-04", "2016-06-05", "2016-06-06", "2016-06-07", "2016-06-08", "2016-06-09", "2016-06-10", "2016-06-11", "2016-06-12", "2016-06-13", "2016-06-14", "2016-06-15", "2016-06-16", "2016-06-17", "2016-06-18", "2016-06-19", "2016-06-20", "2016-06-21", "2016-06-22", "2016-06-23", "2016-06-24", "2016-06-25", "2016-06-26", "2016-06-27", "2016-06-28", "2016-06-29", "2016-06-30", "2016-07-01", "2016-07-02", "2016-07-03", "2016-07-04", "2016-07-05", "2016-07-06", "2016-07-07", "2016-07-08", "2016-07-09", "2016-07-10", "2016-07-11", "2016-07-12", "2016-07-13", "2016-07-14", "2016-07-15", "2016-07-16", "2016-07-17", "2016-07-18", "2016-07-19", "2016-07-20", "2016-07-21", "2016-07-22", "2016-07-23", "2016-07-24", "2016-03-21", "2016-03-23", "2016-03-24", "2016-03-25", "2016-03-26", "2016-03-27", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-02", "2016-04-03", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-08", "2016-04-10", "2016-04-11", "2016-04-12", "2016-04-14", "2016-04-16", "2016-04-17", "2016-04-18", "2016-04-19", "2016-04-21", "2016-04-22", "2016-04-23", "2016-04-24", "2016-04-26", "2016-04-27", "2016-04-29", "2016-04-30", "2016-05-02", "2016-05-03", "2016-05-04", "2016-05-06", "2016-05-07", "2016-05-08", "2016-05-10", "2016-05-14", "2016-05-23", "2016-05-25", "2016-05-27", "2016-05-28", "2016-05-30", "2016-05-31", "2016-06-01", "2016-06-03", "2016-06-04", "2016-06-05", "2016-06-06", "2016-06-08", "2016-06-09", "2016-06-12", "2016-06-13", "2016-06-14", "2016-06-17", "2016-06-22", "2016-06-26", "2016-06-29", "2016-07-02", "2016-07-03", "2016-07-04", "2016-07-05", "2016-07-13", "2016-07-14", "2016-07-16", "2016-07-17", "2016-07-18", "2016-07-20", "2016-07-21", "2016-07-22", "2016-07-23", "2016-03-21", "2016-03-22", "2016-03-23", "2016-03-24", "2016-03-25", "2016-03-26", "2016-03-27", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-01", "2016-04-02", "2016-04-03", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-07", "2016-04-08", "2016-04-09", "2016-04-10", "2016-04-11", "2016-04-12", "2016-04-13", "2016-04-14", "2016-04-15", "2016-04-16", "2016-04-17", "20 ...
